# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pydataset import data

import seaborn as sns

iris = data('iris') #use sns data set download for clearer data
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %%
iris
# Out:
#      Sepal.Length  Sepal.Width  petal_length  petal_width     Species
# 1             5.1          3.5           1.4          0.2      setosa
# 2             4.9          3.0           1.4          0.2      setosa
# 3             4.7          3.2           1.3          0.2      setosa
# 4             4.6          3.1           1.5          0.2      setosa
# 5             5.0          3.6           1.4          0.2      setosa
# 6             5.4          3.9           1.7          0.4      setosa
# 7             4.6          3.4           1.4          0.3      setosa
# 8             5.0          3.4           1.5          0.2      setosa
# 9             4.4          2.9           1.4          0.2      setosa
# 10            4.9          3.1           1.5          0.1      setosa
# 11            5.4          3.7           1.5          0.2      setosa
# 12            4.8          3.4           1.6          0.2      setosa
# ...

# %% [markdown]
# What does the distribution of petal lengths look like?
# Is there a correlation between petal length and petal width? Use http://guessthecorrelation.com/ as a hint to how we could visually determine if a correlation exists between two numeric columns.
# Would it be reasonable to predict species based on sepal width and sepal length? For this, you'll visualize two numeric columns through the lense of a categorical column.
# Which features would be best used to predict species?

# %%
iris=iris.rename(columns = {'Petal.Length' :'petal_length', 'Petal.Width':'petal_width'}, inplace = False)

# %%
sns.displot(iris.petal_length, kde =True)

# %%
sns.pairplot(data = iris, hue = 'species') #conduct pairplots first to visualize the data correlations

# %%
# What does the distribution of petal lengths look like?

plt.figure(figsize=(12, 10))
plt.suptitle('Boxplots with Seaborn')

plt.subplot(221)
sns.kdeplot(data=iris, x='petal_length', hue='species')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Density'>

# %%
# Is there a correlation between petal length and petal width? Use http://guessthecorrelation.com/ as a hint to how we could visually determine if a correlation exists between two numeric columns.
corr=iris.corr()
sns.heatmap(corr, cmap = 'Blues', annot = True, square = True )
#
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(data=iris, x="petal_length", y="petal_width", hue = "species")
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
# Would it be reasonable to predict species based on sepal width and sepal length? For this, you'll visualize two numeric columns through the lense of a categorical column.
# sns.pairplot(iris, corner = True)
iris = sns.load_dataset("iris")
sns.scatterplot(data=iris, x="sepal_length", y="sepal_width", hue = "species")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
# Which features would be best used to predict species?
sns.boxplot(y = 'sepal_length', x = 'species', data = iris)
# box plotshows how some verginica and vesicolor overlap each other however sestosa shows a distinct variation
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %% [markdown]
# Using the lesson as an example, use seaborn's load_dataset function to load the anscombe data set. Use pandas to group the data by the dataset column, and calculate summary statistics for each dataset. What do you notice?
# Plot the x and y values from the anscombe data. Each dataset should be in a separate column.

# %%
anscombe = sns.load_dataset('anscombe')

# %%
anscombe.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
anscombe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dataset  44 non-null     object
#  1   x        44 non-null     float64
#  2   y        44 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.2+ KB

# %%
anscombe.describe()
sns.relplot(data= anscombe, x='x', y='y', col = 'dataset')
# df.groupby('dataset').describe()

# %%
sns.lmplot(data= anscombe, x='x', y='y', col = 'dataset') 
#line plot on a 2 dimensional plane, cs= to 0 to have the regression line 
# you have to visualize the data in order to make a decision on the outliers

# %%
# anscombe = anscombe.groupby('dataset').x.describe()

# %%
anscombe.index
# Out:
# Index(['I', 'II', 'III', 'IV'], dtype='object', name='dataset')

# %%
sns.barplot(data= anscombe, x='x', y='y', hue = 'dataset')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
sns.pairplot(data = anscombe, hue = 'dataset') #conduct pairplots first to visualize the data correlations

# %%
insectsprays = data('InsectSprays')
insectsprays.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72 entries, 1 to 72
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   count   72 non-null     int64
#  1   spray   72 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 1.7+ KB

# %%
insectsprays.sample(5)
# Out:
#     count spray
# 42      3     D
# 62      9     F
# 41      4     D
# 51      3     E
# 64     22     F

# %%
sns.boxplot(x="spray",y= "count", data = insectsprays)
# median is not influenced as such by outliers... unlike mean
# c/d are more effective
# Out:
# <AxesSubplot:xlabel='spray', ylabel='count'>

# %%
swiss = data('swiss')
swiss.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality
# Courtelary                22.2
# Delemont                  22.2
# Franches-Mnt              20.2
# Moutier                   20.3
# Neuveville                20.6

# %%
data('swiss').describe()
# Out:
#        Fertility  Agriculture  Examination  Education   Catholic  \
# count  47.000000    47.000000    47.000000  47.000000   47.00000
# mean   70.142553    50.659574    16.489362  10.978723   41.14383
# std    12.491697    22.711218     7.977883   9.615407   41.70485
# min    35.000000     1.200000     3.000000   1.000000    2.15000
# 25%    64.700000    35.900000    12.000000   6.000000    5.19500
# 50%    70.400000    54.100000    16.000000   8.000000   15.14000
# 75%    78.450000    67.650000    22.000000  12.000000   93.12500
# max    92.500000    89.700000    37.000000  53.000000  100.00000
#
#        Infant.Mortality
# count         47.000000
# mean          19.942553
# std            2.912697
# min           10.800000
# 25%           18.150000
# 50%           20.000000
# 75%           21.700000
# max           26.600000

# %%
swiss.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality
# Courtelary                22.2
# Delemont                  22.2
# Franches-Mnt              20.2
# Moutier                   20.3
# Neuveville                20.6

# %%
sns.pairplot(data = swiss, hue = 'Catholic') #conduct pairplots first to visualize the data correlations

# %% [markdown]
# Create an attribute named is_catholic that holds a boolean value of whether or not the province is Catholic. (Choose a cutoff point for what constitutes catholic)

# %%
sns.barplot(y= 'Catholic', data=swiss, estimator =np.mean)
# Out:
# <AxesSubplot:ylabel='Catholic'>

# %%
swiss['is_catholic'] = swiss.Catholic>60
swiss.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality  is_catholic
# Courtelary                22.2        False
# Delemont                  22.2         True
# Franches-Mnt              20.2         True
# Moutier                   20.3        False
# Neuveville                20.6        False

# %%
sns.boxplot(x="is_catholic",y= "Fertility", data = swiss)
# Out:
# <AxesSubplot:xlabel='is_catholic', ylabel='Fertility'>

# %% [markdown]
# -Does whether or not a province is Catholic influence fertility?
# It appears that the higher the catholic population the higher the fertility rate

# %%
swiss.groupby('is_catholic').Fertility.mean()
# Out:
# is_catholic
# False    64.770968
# True     80.550000
# Name: Fertility, dtype: float64

# %% [markdown]
# What measure correlates most strongly with fertility?
# Catholicsm

# %%
corr=swiss.corr()
corr
# Out:
#                   Fertility  Agriculture  Examination  Education  Catholic  \
# Fertility          1.000000     0.353079    -0.645883  -0.663789  0.463685
# Agriculture        0.353079     1.000000    -0.686542  -0.639523  0.401095
# Examination       -0.645883    -0.686542     1.000000   0.698415 -0.572742
# Education         -0.663789    -0.639523     0.698415   1.000000 -0.153859
# Catholic           0.463685     0.401095    -0.572742  -0.153859  1.000000
# Infant.Mortality   0.416556    -0.060859    -0.114022  -0.099322  0.175496
# is_catholic        0.605023     0.475120    -0.641897  -0.328808  0.957798
#
#                   Infant.Mortality  is_catholic
# Fertility                 0.416556     0.605023
# Agriculture              -0.060859     0.475120
# Examination              -0.114022    -0.641897
# Education                -0.099322    -0.328808
# Catholic                  0.175496     0.957798
# Infant.Mortality          1.000000     0.207544
# ...

# %%
corr=swiss.corr()
sns.heatmap(corr, cmap = 'RdBu', annot = True, square = True )
# education is more correlated to fertility
# Out:
# <AxesSubplot:>

# %% [markdown]
# Using the chipotle dataset from the previous exercise, create a bar chart that shows the 4 most popular items and the revenue produced by each.

# %%
from env import get_db_url
url = get_db_url("chipotle")
chip= pd.read_sql('SELECT * FROM orders', url )

# %%
chip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  4622 non-null   int64
#  1   order_id            4622 non-null   int64
#  2   quantity            4622 non-null   int64
#  3   item_name           4622 non-null   object
#  4   choice_description  4622 non-null   object
#  5   item_price          4622 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 216.8+ KB

# %%
chip["item_price"]= chip["item_price"].replace('$', '').astype(float)

chip.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#    item_price
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98

# %%
popular_items = chip.groupby('item_name').quantity.sum().nlargest(4)
popular_items
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Steak Burrito          386
# Name: quantity, dtype: int64

# %%
revenue = chip[chip.item_name.isin(popular_items.index)].groupby('item_name').item_price.sum().reset_index()
revenue
# Out:
#              item_name  item_price
# 0         Chicken Bowl     7342.73
# 1      Chicken Burrito     5575.82
# 2  Chips and Guacamole     2201.04
# 3        Steak Burrito     3851.43

# %%
plt.figure(figsize = (8, 5))

sns.barplot(data = revenue, y= 'item_name', x = 'item_price')
# Out:
# <AxesSubplot:xlabel='item_price', ylabel='item_name'>

# %%
sleepstudy = data('sleepstudy')
sleepstudy['Subject'] = 'Subject_' + sleepstudy.Subject.astype(str) 
sleepstudy.head()
# Out:
#    Reaction  Days      Subject
# 1  249.5600     0  Subject_308
# 2  258.7047     1  Subject_308
# 3  250.8006     2  Subject_308
# 4  321.4398     3  Subject_308
# 5  356.8519     4  Subject_308

# %%
plt.figure(figsize=(16, 9))

sns.lineplot(data = sleepstudy, x = 'Days', y = 'Reaction', hue = 'Subject', legend=False)
sns.lineplot(data = sleepstudy, x = 'Days', y = 'Reaction', color = 'red', linestyle='--', estimator = 'mean')
plt.annotate('Average',(0,265),fontsize=17)
# Out:
# Text(0, 265, 'Average')
