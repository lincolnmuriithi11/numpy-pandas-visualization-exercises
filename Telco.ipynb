# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("Telco.csv")

# %%
cd_df = contract_description = pd.read_clipboard()
cd_df
# Out:
#    contract_id contract_description
# 0            0       Month-to-Month
# 1            1               1 Year
# 2            2               2 Year

# %%
ps_df = phone_ser_des = pd.read_clipboard()
ps_df
# Out:
#    phone_service_id phone_service_description
# 0                 0          No Phone Service
# 1                 1                  One Line
# 2                 2         Two or More Lines

# %%
is_df=int_ser_desc = pd.read_clipboard()
is_df
# Out:
#    internet_service_id internet_service_description
# 0                    0          No Internet Service
# 1                    1                          DSL
# 2                    2                  Fiber Optic

# %%
df["internet_service_id"]= df["internet_service"]

# %%
df["phone_service_id"]= df["phone_service"]

# %%
df["contract_id"]= df["contract_type"]
df
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                  0     Yes        Yes              1
# 1     0003-MKNFE    Male                  0      No         No              2
# 2     0004-TLHLJ    Male                  0      No         No              1
# 3     0011-IGKFF    Male                  1     Yes         No              1
# 4     0013-EXCHZ  Female                  1     Yes         No              1
# ...          ...     ...                ...     ...        ...            ...
# 7044  9987-LUTYD  Female                  0      No         No              1
# 7045  9992-RRAMN    Male                  0     Yes         No              2
# 7046  9992-UJOEL    Male                  0      No         No              1
# 7047  9993-LHIEB    Male                  0     Yes        Yes              1
# 7048  9995-HOTOH    Male                  0     Yes        Yes              0
#
# ...

# %%
df["customer_id"].nunique()
# Out:
# 7043

# %%
# df1.merge(df2, how='inner', on='a')
df = df.merge(cd_df, how = "inner", on ="contract_id")
df
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                  0     Yes        Yes              1
# 1     0020-JDNXP  Female                  0     Yes        Yes              0
# 2     0022-TCJCI    Male                  1      No         No              1
# 3     0023-UYUPN  Female                  1     Yes         No              2
# 4     0036-IHMOT  Female                  0     Yes        Yes              1
# ...          ...     ...                ...     ...        ...            ...
# 7044  0040-HALCW    Male                  0     Yes        Yes              1
# 7045  0042-RLHYP  Female                  0     Yes        Yes              1
# 7046  9975-GPKZU    Male                  0     Yes        Yes              1
# 7047  9993-LHIEB    Male                  0     Yes        Yes              1
# 7048  9995-HOTOH    Male                  0     Yes        Yes              0
#
# ...

# %%
df = df.merge(is_df, how = "inner", on ="internet_service_id")
df
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                  0     Yes        Yes              1
# 1     0020-JDNXP  Female                  0     Yes        Yes              0
# 2     0022-TCJCI    Male                  1      No         No              1
# 3     0068-FIGTF  Female                  0      No         No              1
# 4     0074-HDKDG    Male                  0     Yes        Yes              1
# ...          ...     ...                ...     ...        ...            ...
# 7044  9924-JPRMC    Male                  0      No         No              2
# 7045  9933-QRGTX  Female                  0     Yes         No              1
# 7046  9938-TKDGL    Male                  0     Yes        Yes              1
# 7047  9958-MEKUC    Male                  0     Yes        Yes              2
# 7048  9959-WOFKT    Male                  0      No        Yes              2
#
# ...

# %%
df = df.merge(ps_df, how = "inner", on ="phone_service_id")
df
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                  0     Yes        Yes              1
# 1     0022-TCJCI    Male                  1      No         No              1
# 2     0068-FIGTF  Female                  0      No         No              1
# 3     0074-HDKDG    Male                  0     Yes        Yes              1
# 4     0080-EMYVY  Female                  0      No         No              1
# ...          ...     ...                ...     ...        ...            ...
# 7044  9861-PDSZP  Female                  0      No         No              2
# 7045  9866-OCCKE  Female                  1     Yes         No              2
# 7046  9924-JPRMC    Male                  0      No         No              2
# 7047  9958-MEKUC    Male                  0     Yes        Yes              2
# 7048  9959-WOFKT    Male                  0      No        Yes              2
#
# ...

# %%
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                  0     Yes        Yes              1
# 1     0020-JDNXP  Female                  0     Yes        Yes              0
# 2     0022-TCJCI    Male                  1      No         No              1
# 3     0023-UYUPN  Female                  1     Yes         No              2
# 4     0036-IHMOT  Female                  0     Yes        Yes              1
# ...          ...     ...                ...     ...        ...            ...
# 7044  0040-HALCW    Male                  0     Yes        Yes              1
# 7045  0042-RLHYP  Female                  0     Yes        Yes              1
# 7046  9975-GPKZU    Male                  0     Yes        Yes              1
# 7047  9993-LHIEB    Male                  0     Yes        Yes              1
# 7048  9995-HOTOH    Male                  0     Yes        Yes              0
#
# ...

# %%
df["contract_id"].value_counts()
# Out:
# 0    3876
# 2    1697
# 1    1476
# Name: contract_id, dtype: int64

# %%
df["contract_type"].value_counts()
# Out:
# 0    3876
# 2    1697
# 1    1476
# Name: contract_type, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7049 entries, 0 to 7048
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        7049 non-null   object
#  1   gender             7049 non-null   object
#  2   is_senior_citizen  7049 non-null   int64
#  3   partner            7049 non-null   object
#  4   dependents         7049 non-null   object
#  5   phone_service      7049 non-null   int64
#  6   internet_service   7049 non-null   int64
#  7   contract_type      7049 non-null   int64
#  8   payment_type       7049 non-null   object
#  9   monthly_charges    7049 non-null   float64
#  10  total_charges      7038 non-null   float64
#  11  churn              7049 non-null   object
#  12  tenure             7049 non-null   float64
# dtypes: float64(3), int64(4), object(6)
# memory usage: 716.0+ KB

# %%
df
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                  0     Yes        Yes              1
# 1     0003-MKNFE    Male                  0      No         No              2
# 2     0004-TLHLJ    Male                  0      No         No              1
# 3     0011-IGKFF    Male                  1     Yes         No              1
# 4     0013-EXCHZ  Female                  1     Yes         No              1
# ...          ...     ...                ...     ...        ...            ...
# 7044  9987-LUTYD  Female                  0      No         No              1
# 7045  9992-RRAMN    Male                  0     Yes         No              2
# 7046  9992-UJOEL    Male                  0      No         No              1
# 7047  9993-LHIEB    Male                  0     Yes        Yes              1
# 7048  9995-HOTOH    Male                  0     Yes        Yes              0
#
# ...

# %%
sns.boxplot(x= "churn", y = "monthly_charges",data = df)
# Out:
# <AxesSubplot:xlabel='churn', ylabel='monthly_charges'>

# %%
sns.barplot(x= "churn", y = "contract_type",data = df)
# Out:
# <AxesSubplot:xlabel='churn', ylabel='contract_type'>

# %%
df["phone_internet"] = (df.phone_service > 0 ) & (df.internet_service > 0)
df
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                  0     Yes        Yes              1
# 1     0022-TCJCI    Male                  1      No         No              1
# 2     0068-FIGTF  Female                  0      No         No              1
# 3     0074-HDKDG    Male                  0     Yes        Yes              1
# 4     0080-EMYVY  Female                  0      No         No              1
# ...          ...     ...                ...     ...        ...            ...
# 7044  9861-PDSZP  Female                  0      No         No              2
# 7045  9866-OCCKE  Female                  1     Yes         No              2
# 7046  9924-JPRMC    Male                  0      No         No              2
# 7047  9958-MEKUC    Male                  0     Yes        Yes              2
# 7048  9959-WOFKT    Male                  0      No        Yes              2
#
# ...

# %%
sns.countplot(data= df, x="payment_type",y= "monthly_charges", hue = 'churn')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/qg/y1d1577d6_zdj2rfwsn6lwsh0000gn/T/ipykernel_783/4064584836.py in <module>
# ----> 1 sns.countplot(data= df, x="payment_type",y= "monthly_charges", hue = 'churn')
#
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3594         y = x
#    3595     elif x is not None and y is not None:
# -> 3596         raise ValueError("Cannot pass values for both `x` and `y`")
#    3597
# ...

# %%
df1 = pd.read_clipboard()
# Out:
#    phone_service_id phone_service_description
# 0                 0          No Phone Service
# 1                 1                  One Line
# 2                 2         Two or More Lines

# %%
internet_service_description = pd.read_clipboard()
internet_service_description
# Out:
# Empty DataFrame
# Columns: [internet_service_description, =, pd.read_clipboard()]
# Index: []

# %%
df1 = pd.read_clipboard()
df1
# Out:
# Empty DataFrame
# Columns: [df1, =, pd.read_clipboard()]
# Index: []

# %%
contract_description = pd.read_clipboard()
contract_description
# Out:
#    contract_id contract_description
# 0            0       Month-to-Month
# 1            1               1 Year
# 2            2               2 Year

# %%
pd.DataFrame(df.churn.value_counts(normalize=True))
# Out:
#         churn
# No   0.734714
# Yes  0.265286

# %%
pd.DataFrame(df.is_senior_citizen.value_counts(normalize=True))
# Out:
#    is_senior_citizen
# 0           0.837991
# 1           0.162009

# %%
pd.DataFrame(df.payment_type.value_counts(normalize=True))
# currently the largest payment system is electronic check followed by mailed check
# Out:
#                            payment_type
# Electronic check               0.335509
# Mailed check                   0.228685
# Bank transfer (automatic)      0.219606
# Credit card (automatic)        0.216201

# %%
by_payment = df.groupby("payment_type").churn.value_counts(normalize=True)
by_payment
# largest group to churn = electronic check
# Out:
# payment_type               churn
# Bank transfer (automatic)  No       0.832687
#                            Yes      0.167313
# Credit card (automatic)    No       0.847769
#                            Yes      0.152231
# Electronic check           No       0.547146
#                            Yes      0.452854
# Mailed check               No       0.808933
#                            Yes      0.191067
# Name: churn, dtype: float64

# %%
by_payment.unstack()
# Out:
# churn                            No       Yes
# payment_type
# Bank transfer (automatic)  0.832687  0.167313
# Credit card (automatic)    0.847769  0.152231
# Electronic check           0.547146  0.452854
# Mailed check               0.808933  0.191067

# %%
by_payment = df.groupby("is_senior_citizen").churn.value_counts(normalize=True)
by_payment
# Out:
# is_senior_citizen  churn
# 0                  No       0.764009
#                    Yes      0.235991
# 1                  No       0.583187
#                    Yes      0.416813
# Name: churn, dtype: float64

# %%
sns.countplot(data= df, y ="payment_type", x = "monthly_charges", hue = 'churn')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/qg/y1d1577d6_zdj2rfwsn6lwsh0000gn/T/ipykernel_783/171274494.py in <module>
# ----> 1 sns.countplot(data= df, y ="payment_type", x = "monthly_charges", hue = 'churn')
#
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3594         y = x
#    3595     elif x is not None and y is not None:
# -> 3596         raise ValueError("Cannot pass values for both `x` and `y`")
#    3597
# ...

# %%
sns.barplot(data= df, x = "monthly_charges", y ="payment_type",  hue = 'churn')
# Out:
# <AxesSubplot:xlabel='monthly_charges', ylabel='payment_type'>

# %%
sns.boxplot(data= df, y = "monthly_charges", x ="is_senior_citizen",  hue = 'churn')
# Out:
# <AxesSubplot:xlabel='is_senior_citizen', ylabel='monthly_charges'>

# %%
100*df['churn'].value_counts()/len(df['churn'])
# finding the churn rate
# Out:
# No     73.471414
# Yes    26.528586
# Name: churn, dtype: float64

# %%
df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7049 entries, 0 to 7048
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        7049 non-null   object
#  1   gender             7049 non-null   object
#  2   is_senior_citizen  7049 non-null   int64
#  3   partner            7049 non-null   object
#  4   dependents         7049 non-null   object
#  5   phone_service      7049 non-null   int64
#  6   internet_service   7049 non-null   int64
#  7   contract_type      7049 non-null   int64
#  8   payment_type       7049 non-null   object
#  9   monthly_charges    7049 non-null   float64
#  10  total_charges      7038 non-null   float64
#  11  churn              7049 non-null   object
#  12  tenure             7049 non-null   float64
# dtypes: float64(3), int64(4), object(6)
# memory usage: 716.0+ KB

# %%
df['tenure'].value_counts()
# Out:
# 1.0     614
# 1.9      49
# 2.1      46
# 2.0      36
# 3.0      32
#        ...
# 74.7      1
# 75.3      1
# 37.4      1
# 75.6      1
# 76.5      1
# Name: tenure, Length: 748, dtype: int64

# %%
dummies_df = pd.get_dummies(df)
dummies_df.head()
# Out:
#    is_senior_citizen  phone_service  internet_service  contract_type  \
# 0                  0              1                 1              1
# 1                  0              2                 1              0
# 2                  0              1                 2              0
# 3                  1              1                 2              0
# 4                  1              1                 2              0
#
#    monthly_charges  total_charges  tenure  customer_id_0002-ORFBO  \
# 0             65.6         593.30     9.0                       1
# 1             59.9         542.40     9.1                       0
# 2             73.9         280.85     3.8                       0
# 3             98.0        1237.85    12.6                       0
# 4             83.9         267.40     3.2                       0
#
#    customer_id_0003-MKNFE  customer_id_0004-TLHLJ  ...  partner_No  \
# 0                       0                       0  ...           0
# ...

# %%
sns.boxplot(data=df,y='tenure',x='churn')
# Out:
# <AxesSubplot:xlabel='churn', ylabel='tenure'>

# %%
sns.boxplot(data= df, x = "monthly_charges", y ="payment_type"=='Electronic check',  hue = 'churn')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/qg/y1d1577d6_zdj2rfwsn6lwsh0000gn/T/ipykernel_783/775017448.py in <module>
# ----> 1 sns.boxplot(data= df, x = "monthly_charges", y ="payment_type"=='Electronic check',  hue = 'churn')
#
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2241 ):
#    2242
# -> 2243     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
# ...

# %%
# converting str to int type
# Ploting Values
plt.figure(figsize=(12,7))
sns.heatmap(df.corr(),annot=True,fmt=".1f")
# Out:
# <AxesSubplot:>

# %%
for i, predictor in enumerate(df.drop(columns=['churn', 'total_charges', 'monthly_charges'])):
    plt.figure(i)
    sns.countplot(data=df, x=predictor, hue='churn')
