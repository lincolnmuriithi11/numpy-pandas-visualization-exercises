# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("Telco.csv")

# %%
contract_description = pd.read_clipboard()
contract_description
# Out:
#    contract_id contract_description
# 0            0       Month-to-Month
# 1            1               1 Year
# 2            2               2 Year

# %%
phone_ser_des = pd.read_clipboard()
phone_ser_des
# Out:
#    phone_service_id phone_service_description
# 0                 0          No Phone Service
# 1                 1                  One Line
# 2                 2         Two or More Lines

# %%
int_ser_desc = pd.read_clipboard()
int_ser_desc
# Out:
#    internet_service_id internet_service_description
# 0                    0          No Internet Service
# 1                    1                          DSL
# 2                    2                  Fiber Optic

# %%
df["internet_service_id"]= df["internet_service"]

# %%
df["phone_service_id"]= df["phone_service"]

# %%
df["contract_id"]= df["contract_type"]
df
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                  0     Yes        Yes              1
# 1     0003-MKNFE    Male                  0      No         No              2
# 2     0004-TLHLJ    Male                  0      No         No              1
# 3     0011-IGKFF    Male                  1     Yes         No              1
# 4     0013-EXCHZ  Female                  1     Yes         No              1
# ...          ...     ...                ...     ...        ...            ...
# 7044  9987-LUTYD  Female                  0      No         No              1
# 7045  9992-RRAMN    Male                  0     Yes         No              2
# 7046  9992-UJOEL    Male                  0      No         No              1
# 7047  9993-LHIEB    Male                  0     Yes        Yes              1
# 7048  9995-HOTOH    Male                  0     Yes        Yes              0
#
#       internet_service  contract_type      payment_type  monthly_charges  \
# 0                    1              1      Mailed check            65.60
# 1                    1              0      Mailed check            59.90
# 2                    2              0  Electronic check            73.90
# 3                    2              0  Electronic check            98.00
# 4                    2              0      Mailed check            83.90
# ...                ...            ...               ...              ...
# 7044                 1              1      Mailed check            55.15
# 7045                 2              0  Electronic check            85.10
# 7046                 1              0      Mailed check            50.30
# 7047                 1              2      Mailed check            67.85
# 7048                 1              2  Electronic check            59.00
#
#       total_charges churn  tenure  internet_service_id  contract_id
# 0            593.30    No     9.0                    1            1
# 1            542.40    No     9.1                    1            0
# 2            280.85   Yes     3.8                    2            0
# 3           1237.85   Yes    12.6                    2            0
# 4            267.40   Yes     3.2                    2            0
# ...             ...   ...     ...                  ...          ...
# 7044         742.90    No    13.5                    1            1
# 7045        1873.70   Yes    22.0                    2            0
# 7046          92.75    No     1.8                    1            0
# 7047        4627.65    No    68.2                    1            2
# 7048        3707.60    No    62.8                    1            2
#
# [7049 rows x 15 columns]

# %%
# df1.merge(df2, how='inner', on='a')
df = df.merge(contract_description, how = "inner", on ="contract_id")
df
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                  0     Yes        Yes              1
# 1     0020-JDNXP  Female                  0     Yes        Yes              0
# 2     0022-TCJCI    Male                  1      No         No              1
# 3     0023-UYUPN  Female                  1     Yes         No              2
# 4     0036-IHMOT  Female                  0     Yes        Yes              1
# ...          ...     ...                ...     ...        ...            ...
# 7044  0040-HALCW    Male                  0     Yes        Yes              1
# 7045  0042-RLHYP  Female                  0     Yes        Yes              1
# 7046  9975-GPKZU    Male                  0     Yes        Yes              1
# 7047  9993-LHIEB    Male                  0     Yes        Yes              1
# 7048  9995-HOTOH    Male                  0     Yes        Yes              0
#
#       internet_service  contract_type               payment_type  \
# 0                    1              1               Mailed check
# 1                    1              1               Mailed check
# 2                    1              1    Credit card (automatic)
# 3                    0              1           Electronic check
# 4                    2              1  Bank transfer (automatic)
# ...                ...            ...                        ...
# 7044                 0              2    Credit card (automatic)
# 7045                 0              2  Bank transfer (automatic)
# 7046                 0              2    Credit card (automatic)
# 7047                 1              2               Mailed check
# 7048                 1              2           Electronic check
#
#       monthly_charges  total_charges churn  tenure  internet_service_id  \
# 0               65.60         593.30    No     9.0                    1
# 1               61.25        1993.20    No    32.5                    1
# 2               62.70        2791.50   Yes    44.5                    1
# 3               25.20        1306.30    No    51.8                    0
# 4              103.70        5656.75    No    54.5                    2
# ...               ...            ...   ...     ...                  ...
# 7044            20.40        1090.60    No    53.5                    0
# 7045            19.70        1396.90    No    70.9                    0
# 7046            19.75         856.50    No    43.4                    0
# 7047            67.85        4627.65    No    68.2                    1
# 7048            59.00        3707.60    No    62.8                    1
#
#       contract_id contract_description_x contract_description_y
# 0               1                 1 Year                 1 Year
# 1               1                 1 Year                 1 Year
# 2               1                 1 Year                 1 Year
# 3               1                 1 Year                 1 Year
# 4               1                 1 Year                 1 Year
# ...           ...                    ...                    ...
# 7044            2                 2 Year                 2 Year
# 7045            2                 2 Year                 2 Year
# 7046            2                 2 Year                 2 Year
# 7047            2                 2 Year                 2 Year
# 7048            2                 2 Year                 2 Year
#
# [7049 rows x 17 columns]

# %%
df = df.merge(internet_service_description, how = "inner", on ="internet_service_id")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/qg/y1d1577d6_zdj2rfwsn6lwsh0000gn/T/ipykernel_45534/2629840193.py in <module>
# ----> 1 df = df.merge(internet_service_description, how = "inner", on ="internet_service_id")
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9188         from pandas.core.reshape.merge import merge
#    9189
# -> 9190         return merge(
#    9191             self,
#    9192             right,
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     697             self.right_join_keys,
#     698             self.join_names,
# --> 699         ) = self._get_merge_keys()
#     700
#     701         # validate the merge keys dtypes. We may need to coerce
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1094                     if not is_rkey(rk):
#    1095                         if rk is not None:
# -> 1096                             right_keys.append(right._get_label_or_level_values(rk))
#    1097                         else:
#    1098                             # work-around for merge_asof(right_index=True)
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: 'internet_service_id'

# %%
df
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                  0     Yes        Yes              1
# 1     0020-JDNXP  Female                  0     Yes        Yes              0
# 2     0022-TCJCI    Male                  1      No         No              1
# 3     0023-UYUPN  Female                  1     Yes         No              2
# 4     0036-IHMOT  Female                  0     Yes        Yes              1
# ...          ...     ...                ...     ...        ...            ...
# 7044  0040-HALCW    Male                  0     Yes        Yes              1
# 7045  0042-RLHYP  Female                  0     Yes        Yes              1
# 7046  9975-GPKZU    Male                  0     Yes        Yes              1
# 7047  9993-LHIEB    Male                  0     Yes        Yes              1
# 7048  9995-HOTOH    Male                  0     Yes        Yes              0
#
#       internet_service  contract_type               payment_type  \
# 0                    1              1               Mailed check
# 1                    1              1               Mailed check
# 2                    1              1    Credit card (automatic)
# 3                    0              1           Electronic check
# 4                    2              1  Bank transfer (automatic)
# ...                ...            ...                        ...
# 7044                 0              2    Credit card (automatic)
# 7045                 0              2  Bank transfer (automatic)
# 7046                 0              2    Credit card (automatic)
# 7047                 1              2               Mailed check
# 7048                 1              2           Electronic check
#
#       monthly_charges  total_charges churn  tenure  contract_id  \
# 0               65.60         593.30    No     9.0            1
# 1               61.25        1993.20    No    32.5            1
# 2               62.70        2791.50   Yes    44.5            1
# 3               25.20        1306.30    No    51.8            1
# 4              103.70        5656.75    No    54.5            1
# ...               ...            ...   ...     ...          ...
# 7044            20.40        1090.60    No    53.5            2
# 7045            19.70        1396.90    No    70.9            2
# 7046            19.75         856.50    No    43.4            2
# 7047            67.85        4627.65    No    68.2            2
# 7048            59.00        3707.60    No    62.8            2
#
#      contract_description
# 0                  1 Year
# 1                  1 Year
# 2                  1 Year
# 3                  1 Year
# 4                  1 Year
# ...                   ...
# 7044               2 Year
# 7045               2 Year
# 7046               2 Year
# 7047               2 Year
# 7048               2 Year
#
# [7049 rows x 15 columns]

# %%
df["contract_id"].value_counts()
# Out:
# 0    3876
# 2    1697
# 1    1476
# Name: contract_id, dtype: int64

# %%
df["contract_type"].value_counts()
# Out:
# 0    3876
# 2    1697
# 1    1476
# Name: contract_type, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7049 entries, 0 to 7048
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        7049 non-null   object
#  1   gender             7049 non-null   object
#  2   is_senior_citizen  7049 non-null   int64
#  3   partner            7049 non-null   object
#  4   dependents         7049 non-null   object
#  5   phone_service      7049 non-null   int64
#  6   internet_service   7049 non-null   int64
#  7   contract_type      7049 non-null   int64
#  8   payment_type       7049 non-null   object
#  9   monthly_charges    7049 non-null   float64
#  10  total_charges      7038 non-null   float64
#  11  churn              7049 non-null   object
#  12  tenure             7049 non-null   float64
# dtypes: float64(3), int64(4), object(6)
# memory usage: 716.0+ KB

# %%
df
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                  0     Yes        Yes              1
# 1     0003-MKNFE    Male                  0      No         No              2
# 2     0004-TLHLJ    Male                  0      No         No              1
# 3     0011-IGKFF    Male                  1     Yes         No              1
# 4     0013-EXCHZ  Female                  1     Yes         No              1
# ...          ...     ...                ...     ...        ...            ...
# 7044  9987-LUTYD  Female                  0      No         No              1
# 7045  9992-RRAMN    Male                  0     Yes         No              2
# 7046  9992-UJOEL    Male                  0      No         No              1
# 7047  9993-LHIEB    Male                  0     Yes        Yes              1
# 7048  9995-HOTOH    Male                  0     Yes        Yes              0
#
#       internet_service  contract_type      payment_type  monthly_charges  \
# 0                    1              1      Mailed check            65.60
# 1                    1              0      Mailed check            59.90
# 2                    2              0  Electronic check            73.90
# 3                    2              0  Electronic check            98.00
# 4                    2              0      Mailed check            83.90
# ...                ...            ...               ...              ...
# 7044                 1              1      Mailed check            55.15
# 7045                 2              0  Electronic check            85.10
# 7046                 1              0      Mailed check            50.30
# 7047                 1              2      Mailed check            67.85
# 7048                 1              2  Electronic check            59.00
#
#       total_charges churn  tenure
# 0            593.30    No     9.0
# 1            542.40    No     9.1
# 2            280.85   Yes     3.8
# 3           1237.85   Yes    12.6
# 4            267.40   Yes     3.2
# ...             ...   ...     ...
# 7044         742.90    No    13.5
# 7045        1873.70   Yes    22.0
# 7046          92.75    No     1.8
# 7047        4627.65    No    68.2
# 7048        3707.60    No    62.8
#
# [7049 rows x 13 columns]

# %%
sns.boxplot(x= "churn", y = "monthly_charges",data = df)
# Out:
# <AxesSubplot:xlabel='churn', ylabel='monthly_charges'>

# %%
sns.boxplot(x= "churn", y = "contract_type",data = df)
# Out:
# <AxesSubplot:xlabel='churn', ylabel='contract_type'>

# %%
df["phone_internet"] = (df.phone_service > 0 ) & (df.internet_service > 0)
df
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                  0     Yes        Yes              1
# 1     0003-MKNFE    Male                  0      No         No              2
# 2     0004-TLHLJ    Male                  0      No         No              1
# 3     0011-IGKFF    Male                  1     Yes         No              1
# 4     0013-EXCHZ  Female                  1     Yes         No              1
# ...          ...     ...                ...     ...        ...            ...
# 7044  9987-LUTYD  Female                  0      No         No              1
# 7045  9992-RRAMN    Male                  0     Yes         No              2
# 7046  9992-UJOEL    Male                  0      No         No              1
# 7047  9993-LHIEB    Male                  0     Yes        Yes              1
# 7048  9995-HOTOH    Male                  0     Yes        Yes              0
#
#       internet_service  contract_type      payment_type  monthly_charges  \
# 0                    1              1      Mailed check            65.60
# 1                    1              0      Mailed check            59.90
# 2                    2              0  Electronic check            73.90
# 3                    2              0  Electronic check            98.00
# 4                    2              0      Mailed check            83.90
# ...                ...            ...               ...              ...
# 7044                 1              1      Mailed check            55.15
# 7045                 2              0  Electronic check            85.10
# 7046                 1              0      Mailed check            50.30
# 7047                 1              2      Mailed check            67.85
# 7048                 1              2  Electronic check            59.00
#
#       total_charges churn  tenure  phone_internet
# 0            593.30    No     9.0            True
# 1            542.40    No     9.1            True
# 2            280.85   Yes     3.8            True
# 3           1237.85   Yes    12.6            True
# 4            267.40   Yes     3.2            True
# ...             ...   ...     ...             ...
# 7044         742.90    No    13.5            True
# 7045        1873.70   Yes    22.0            True
# 7046          92.75    No     1.8            True
# 7047        4627.65    No    68.2            True
# 7048        3707.60    No    62.8           False
#
# [7049 rows x 14 columns]

# %%
sns.barplot(data= df, x="payment_type", y='churn', hue = 'is_senior_citizen')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/qg/y1d1577d6_zdj2rfwsn6lwsh0000gn/T/ipykernel_45534/2381547330.py in <module>
# ----> 1 sns.barplot(data= df, x="payment_type", y='churn', hue = 'is_senior_citizen')
#
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# -> 3182     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3183                           estimator, ci, n_boot, units, seed,
#    3184                           orient, color, palette, saturation,
#
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1582                  errwidth, capsize, dodge):
#    1583         """Initialize the plotter."""
# -> 1584         self.establish_variables(x, y, hue, data, orient,
#    1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     154
#     155             # Figure out the plotting orientation
# --> 156             orient = infer_orient(
#     157                 x, y, orient, require_numeric=self.require_numeric
#     158             )
#
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/_core.py in infer_orient(x, y, orient, require_numeric)
#    1350     elif require_numeric and "numeric" not in (x_type, y_type):
#    1351         err = "Neither the `x` nor `y` variable appears to be numeric."
# -> 1352         raise TypeError(err)
#    1353
#    1354     else:
#
# TypeError: Neither the `x` nor `y` variable appears to be numeric.

# %%
df1 = pd.read_clipboard()
# Out:
#    phone_service_id phone_service_description
# 0                 0          No Phone Service
# 1                 1                  One Line
# 2                 2         Two or More Lines

# %%
internet_service_description = pd.read_clipboard()
internet_service_description
# Out:
# Empty DataFrame
# Columns: [internet_service_description, =, pd.read_clipboard()]
# Index: []

# %%
df1 = pd.read_clipboard()
df1
# Out:
# Empty DataFrame
# Columns: [df1, =, pd.read_clipboard()]
# Index: []

# %%
contract_description = pd.read_clipboard()
contract_description
# Out:
#    contract_id contract_description
# 0            0       Month-to-Month
# 1            1               1 Year
# 2            2               2 Year
